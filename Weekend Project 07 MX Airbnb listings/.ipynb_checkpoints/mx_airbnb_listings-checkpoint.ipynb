# %%
import pandas as pd
listings = pd.read_csv("listings.csv")
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  22787  https://www.airbnb.com/rooms/22787  20191125095004   2019-11-25
# 1  35797  https://www.airbnb.com/rooms/35797  20191125095004   2019-11-25
# 2  44616  https://www.airbnb.com/rooms/44616  20191125095004   2019-11-25
# 3  58955  https://www.airbnb.com/rooms/58955  20191125095004   2019-11-25
# 4  70644  https://www.airbnb.com/rooms/70644  20191125095004   2019-11-25
#
#                                                 name  \
# 0  Sunny suite w/ queen size bed, inside boutique...
# 1                                        Villa Dante
# 2                                  CONDESA HAUS  B&B
# 3                 Entire beautiful duplex in la Roma
# 4   Beautiful light Studio Coyoacan- full equipped !
#
#                                              summary  \
# 0  This suite inside El Patio 77 - an eco-friendl...
# 1  Dentro de Villa un estudio de arte con futon, ...
# 2  A new concept of hosting in mexico through a b...
# 3  This beautiful apartment is centrally located,...
# 4  COYOACAN designer studio quiet & safe! well eq...
#
#                                                space  \
# 0  El Patio 77 is the first eco-friendly bed and ...
# 1  please go to (URL HIDDEN) and  see the place a...
# 2  Stay with us at this bed & breakfast named CON...
# 3  Amazing 2 floors apartment in La Roma, the bes...
# 4  LIGHT, SPACIOUS, QUIET, FRIENDLY LOCATION. YOU...
#
#                                          description experiences_offered  \
# 0  This suite inside El Patio 77 - an eco-friendl...                none
# 1  Dentro de Villa un estudio de arte con futon, ...                none
# 2  A new concept of hosting in mexico through a b...                none
# 3  This beautiful apartment is centrally located,...                none
# 4  COYOACAN designer studio quiet & safe! well eq...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Up-and-coming San Rafael neighborhood combines...  ...                t
# 1  Centro comercial Santa Fe, parque interlomas y...  ...                f
# 2                                                NaN  ...                f
# 3  La Roma Norte is a beautiful bohemian and arts...  ...                f
# 4  Coyoacan is a beautiful neighborhood famous fo...  ...                t
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               8
# 1                               2
# 2                              10
# 3                               1
# 4                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            8
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.50
# 1                                            0                NaN
# 2                                            0               0.43
# 3                                            0               0.41
# 4                                            0               1.01
#
# [5 rows x 106 columns]

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20571 entries, 0 to 20570
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(23), int64(21), object(62)
# memory usage: 16.6+ MB

# %%
listings.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  2.057100e+04  2.057100e+04            0.0         0.0             0.0
# mean   2.592208e+07  2.019113e+13            NaN         NaN             NaN
# std    1.025173e+07  6.140774e+00            NaN         NaN             NaN
# min    2.278700e+04  2.019113e+13            NaN         NaN             NaN
# 25%    1.856807e+07  2.019113e+13            NaN         NaN             NaN
# 50%    2.742324e+07  2.019113e+13            NaN         NaN             NaN
# 75%    3.472031e+07  2.019113e+13            NaN         NaN             NaN
# max    4.035306e+07  2.019113e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  2.057100e+04                   0.0         20540.000000
# mean   1.095294e+08                   NaN             5.961246
# std    8.740695e+07                   NaN            15.609994
# min    7.365000e+03                   NaN             0.000000
# 25%    3.279156e+07                   NaN             1.000000
# 50%    9.126549e+07                   NaN             2.000000
# 75%    1.746317e+08                   NaN             4.000000
# max    3.119058e+08                   NaN           424.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed  ...  \
# count               20540.000000                           0.0  ...
# mean                    5.961246                           NaN  ...
# std                    15.609994                           NaN  ...
# min                     0.000000                           NaN  ...
# 25%                     1.000000                           NaN  ...
# 50%                     2.000000                           NaN  ...
# 75%                     4.000000                           NaN  ...
# max                   424.000000                           NaN  ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               15905.000000           15902.000000
# mean                    9.612700               9.832285
# std                     0.891647               0.668202
# min                     2.000000               2.000000
# 25%                     9.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                 15906.000000            15901.000000
# mean                      9.797624                9.817873
# std                       0.755304                0.664110
# min                       2.000000                2.000000
# 25%                      10.000000               10.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count         15900.000000                    20571.000000
# mean              9.608805                        4.714744
# std               0.861311                        8.391954
# min               2.000000                        1.000000
# 25%               9.000000                        1.000000
# 50%              10.000000                        2.000000
# 75%              10.000000                        4.000000
# max              10.000000                       58.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 20571.000000
# mean                                      2.884692
# std                                       7.295594
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                      58.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  20571.000000
# mean                                       1.510719
# std                                        3.144165
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        2.000000
# max                                       30.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 20571.000000       16170.000000
# mean                                      0.079821           1.825876
# std                                       0.817258           1.858464
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.450000
# 50%                                       0.000000           1.190000
# 75%                                       0.000000           2.630000
# max                                      20.000000          17.320000
#
# [8 rows x 44 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
listings.hist(bins= 50, figsize=(20,15))
plt.show()

# %%
import numpy as np

def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data)*test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

train_set, test_set = split_train_test(listings, 0.2)
print(len(train_set), "train +", len(test_set), "test")
# Out:
# 16457 train + 4114 test

# %%
train_set.head()
# Out:
#              id                            listing_url       scrape_id  \
# 7671   22672490  https://www.airbnb.com/rooms/22672490  20191125095004
# 9671   26185023  https://www.airbnb.com/rooms/26185023  20191125095004
# 10334  27495526  https://www.airbnb.com/rooms/27495526  20191125095004
# 4356   17136259  https://www.airbnb.com/rooms/17136259  20191125095004
# 1413    8346216   https://www.airbnb.com/rooms/8346216  20191125095004
#
#       last_scraped                                               name  \
# 7671    2019-11-25     Tu depa en Polanco / Your apartment in Polanco
# 9671    2019-11-25  Beautiful downtown apartment with an amazing v...
# 10334   2019-11-25                                     Cueva de lobos
# 4356    2019-11-25                                    Beautiful room.
# 1413    2019-11-25  Entire  apartment, prívate  bathroom and kitchen.
#
#                                                  summary  \
# 7671   Ideal para viaje de negocios o placer, solo o ...
# 9671   Right in the middle of the hustle and bustle o...
# 10334  Cozy fully-equipped house between the airport ...
# 4356   My place is two blocks from Plaza Carso - an i...
# 1413   Private loft: Loft  is inside a house. King be...
#
#                                                    space  \
# 7671                                                 NaN
# 9671                                                 NaN
# 10334  Our place is extremly cozy, you won't want to ...
# 4356                                                 NaN
# 1413                                                 NaN
#
#                                              description experiences_offered  \
# 7671   Ideal para viaje de negocios o placer, solo o ...                none
# 9671   Right in the middle of the hustle and bustle o...                none
# 10334  Cozy fully-equipped house between the airport ...                none
# 4356   My place is two blocks from Plaza Carso - an i...                none
# 1413   Private loft: Loft  is inside a house. King be...                none
#
#                                    neighborhood_overview  ...  \
# 7671   Se encuentra ubicado a dos cuadras de Plaza Ca...  ...
# 9671   This is a safe and friendly neighborhood, the ...  ...
# 10334  The neighborhood is safe and it's two blocks a...  ...
# 4356   There is a police checkpoint outside in our st...  ...
# 1413                                                 NaN  ...
#
#       instant_bookable is_business_travel_ready cancellation_policy  \
# 7671                 t                        f            moderate
# 9671                 t                        f            flexible
# 10334                f                        f            moderate
# 4356                 f                        f            flexible
# 1413                 t                        f            moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 7671                              f                                f
# 9671                              f                                f
# 10334                             f                                f
# 4356                              f                                f
# 1413                              f                                f
#
#        calculated_host_listings_count  \
# 7671                                2
# 9671                                1
# 10334                               1
# 4356                                2
# 1413                                3
#
#        calculated_host_listings_count_entire_homes  \
# 7671                                             2
# 9671                                             0
# 10334                                            1
# 4356                                             0
# 1413                                             2
#
#       calculated_host_listings_count_private_rooms  \
# 7671                                             0
# 9671                                             1
# 10334                                            0
# 4356                                             2
# 1413                                             1
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 7671                                             0               2.05
# 9671                                             0               0.70
# 10334                                            0               2.84
# 4356                                             0               1.16
# 1413                                             0               3.42
#
# [5 rows x 106 columns]

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(listings, test_size=0.2, random_state=42)

# %%
train_set.head()
# Out:
#              id                            listing_url       scrape_id  \
# 9671   26185023  https://www.airbnb.com/rooms/26185023  20191125095004
# 10334  27495526  https://www.airbnb.com/rooms/27495526  20191125095004
# 4356   17136259  https://www.airbnb.com/rooms/17136259  20191125095004
# 1413    8346216   https://www.airbnb.com/rooms/8346216  20191125095004
# 1130    7174238   https://www.airbnb.com/rooms/7174238  20191125095004
#
#       last_scraped                                               name  \
# 9671    2019-11-25  Beautiful downtown apartment with an amazing v...
# 10334   2019-11-25                                     Cueva de lobos
# 4356    2019-11-25                                    Beautiful room.
# 1413    2019-11-25  Entire  apartment, prívate  bathroom and kitchen.
# 1130    2019-11-25                Cozy Studio near Museo Antropologia
#
#                                                  summary  \
# 9671   Right in the middle of the hustle and bustle o...
# 10334  Cozy fully-equipped house between the airport ...
# 4356   My place is two blocks from Plaza Carso - an i...
# 1413   Private loft: Loft  is inside a house. King be...
# 1130   Fully furnished studio walking distance from M...
#
#                                                    space  \
# 9671                                                 NaN
# 10334  Our place is extremly cozy, you won't want to ...
# 4356                                                 NaN
# 1413                                                 NaN
# 1130   Access to the studio is completely independent...
#
#                                              description experiences_offered  \
# 9671   Right in the middle of the hustle and bustle o...                none
# 10334  Cozy fully-equipped house between the airport ...                none
# 4356   My place is two blocks from Plaza Carso - an i...                none
# 1413   Private loft: Loft  is inside a house. King be...                none
# 1130   Fully furnished studio walking distance from M...                none
#
#                                    neighborhood_overview  ...  \
# 9671   This is a safe and friendly neighborhood, the ...  ...
# 10334  The neighborhood is safe and it's two blocks a...  ...
# 4356   There is a police checkpoint outside in our st...  ...
# 1413                                                 NaN  ...
# 1130   Behind The Camino Real Hotel, in a quiet neigh...  ...
#
#       instant_bookable is_business_travel_ready cancellation_policy  \
# 9671                 t                        f            flexible
# 10334                f                        f            moderate
# 4356                 f                        f            flexible
# 1413                 t                        f            moderate
# 1130                 f                        f            moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 9671                              f                                f
# 10334                             f                                f
# 4356                              f                                f
# 1413                              f                                f
# 1130                              f                                f
#
#        calculated_host_listings_count  \
# 9671                                1
# 10334                               1
# 4356                                2
# 1413                                3
# 1130                                1
#
#        calculated_host_listings_count_entire_homes  \
# 9671                                             0
# 10334                                            1
# 4356                                             0
# 1413                                             2
# 1130                                             1
#
#       calculated_host_listings_count_private_rooms  \
# 9671                                             1
# 10334                                            0
# 4356                                             2
# 1413                                             1
# 1130                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 9671                                             0               0.70
# 10334                                            0               2.84
# 4356                                             0               1.16
# 1413                                             0               3.42
# 1130                                             0               2.84
#
# [5 rows x 106 columns]
